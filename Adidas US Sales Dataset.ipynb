# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("Adidas US Sales Datasets.xlsx")

# %%
df.head()
# Out:
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker      1185732   2020-01-01  Northeast  New York  New York
# 1  Foot Locker      1185732   2020-01-02  Northeast  New York  New York
# 2  Foot Locker      1185732   2020-01-03  Northeast  New York  New York
# 3  Foot Locker      1185732   2020-01-04  Northeast  New York  New York
# 4  Foot Locker      1185732   2020-01-05  Northeast  New York  New York
#
#                      Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear            50.0        1200     600000.0
# 1    Men's Athletic Footwear            50.0        1000     500000.0
# 2    Women's Street Footwear            40.0        1000     400000.0
# 3  Women's Athletic Footwear            45.0         850     382500.0
# 4              Men's Apparel            60.0         900     540000.0
#
#    Operating Profit  Operating Margin Sales Method
# 0          300000.0              0.50     In-store
# ...

# %%
df.tail()
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 9643  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9644  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9645  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9646  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9647  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
#
#             City                  Product  Price per Unit  Units Sold  \
# 9643  Manchester            Men's Apparel            50.0          64
# 9644  Manchester          Women's Apparel            41.0         105
# 9645  Manchester    Men's Street Footwear            41.0         184
# 9646  Manchester  Men's Athletic Footwear            42.0          70
# 9647  Manchester  Women's Street Footwear            29.0          83
#
#       Total Sales  Operating Profit  Operating Margin Sales Method
# ...

# %%
df.isnull().sum()
# Out:
# Retailer            0
# Retailer ID         0
# Invoice Date        0
# Region              0
# State               0
# City                0
# Product             0
# Price per Unit      0
# Units Sold          0
# Total Sales         0
# Operating Profit    0
# Operating Margin    0
# Sales Method        0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Retailer', 'Retailer ID', 'Invoice Date', 'Region', 'State', 'City',
#        'Product', 'Price per Unit', 'Units Sold', 'Total Sales',
#        'Operating Profit', 'Operating Margin', 'Sales Method'],
#       dtype='object')

# %%
df=df.drop("Retailer ID",axis=1)

# %%
df.describe()
# Out:
#        Price per Unit   Units Sold    Total Sales  Operating Profit  \
# count     9648.000000  9648.000000    9648.000000       9648.000000
# mean        45.216625   256.930037   93273.437500      34425.244761
# std         14.705397   214.252030  141916.016727      54193.113713
# min          7.000000     0.000000       0.000000          0.000000
# 25%         35.000000   106.000000    4254.500000       1921.752500
# 50%         45.000000   176.000000    9576.000000       4371.420000
# 75%         55.000000   350.000000  150000.000000      52062.500000
# max        110.000000  1275.000000  825000.000000     390000.000000
#
#        Operating Margin
# count       9648.000000
# mean           0.422991
# std            0.097197
# min            0.100000
# 25%            0.350000
# 50%            0.410000
# 75%            0.490000
# max            0.800000

# %%
sns.boxplot(df['Price per Unit'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price per Unit'>

# %%
q1=df['Price per Unit'].quantile(0.25)

# %%
q3=df['Price per Unit'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['Price per Unit']>lower) & (df['Price per Unit']<upper) ]

# %%
df
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 0     Foot Locker   2020-01-01  Northeast       New York    New York
# 1     Foot Locker   2020-01-02  Northeast       New York    New York
# 2     Foot Locker   2020-01-03  Northeast       New York    New York
# 3     Foot Locker   2020-01-04  Northeast       New York    New York
# 4     Foot Locker   2020-01-05  Northeast       New York    New York
# ...           ...          ...        ...            ...         ...
# 9643  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9644  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9645  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9646  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9647  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# ...

# %%
sns.boxplot(df['Price per Unit'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price per Unit'>

# %%
sns.boxplot(df['Units Sold'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Units Sold'>

# %%
q1=df['Units Sold'].quantile(0.25)

# %%
q3=df['Units Sold'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['Units Sold']>lower) & (df['Units Sold']<upper) ]

# %%
df
# Out:
#            Retailer Invoice Date     Region          State        City  \
# 72    Sports Direct   2020-07-23      South          Texas     Houston
# 77    Sports Direct   2020-07-28      South          Texas     Houston
# 78    Sports Direct   2020-07-29      South          Texas     Houston
# 83    Sports Direct   2020-08-03      South          Texas     Houston
# 84    Sports Direct   2020-08-04      South          Texas     Houston
# ...             ...          ...        ...            ...         ...
# 9643    Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9644    Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9645    Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9646    Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9647    Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# ...

# %%
sns.boxplot(df['Units Sold'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Units Sold'>

# %%
sns.boxplot(df['Total Sales'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Total Sales'>

# %%
q1=df['Total Sales'].quantile(0.25)

# %%
q3=df['Total Sales'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['Total Sales']>lower) & (df['Total Sales']<upper) ]

# %%
df
# Out:
#            Retailer Invoice Date     Region          State        City  \
# 72    Sports Direct   2020-07-23      South          Texas     Houston
# 77    Sports Direct   2020-07-28      South          Texas     Houston
# 78    Sports Direct   2020-07-29      South          Texas     Houston
# 83    Sports Direct   2020-08-03      South          Texas     Houston
# 84    Sports Direct   2020-08-04      South          Texas     Houston
# ...             ...          ...        ...            ...         ...
# 9643    Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9644    Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9645    Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9646    Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9647    Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# ...

# %%
sns.boxplot(df['Total Sales'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Total Sales'>

# %%
sns.boxplot(df['Operating Profit'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Operating Profit'>

# %%
q1=df['Operating Profit'].quantile(0.25)

# %%
q3=df['Operating Profit'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['Operating Profit']>lower) & (df['Operating Profit']<upper) ]

# %%
df
# Out:
#          Retailer Invoice Date     Region          State         City  \
# 285   Foot Locker   2021-06-01       West     California  Los Angeles
# 286   Foot Locker   2021-06-02       West     California  Los Angeles
# 287   Foot Locker   2021-06-03       West     California  Los Angeles
# 288   Foot Locker   2021-06-04    Midwest       Illinois      Chicago
# 291   Foot Locker   2021-06-07    Midwest       Illinois      Chicago
# ...           ...          ...        ...            ...          ...
# 9643  Foot Locker   2021-01-24  Northeast  New Hampshire   Manchester
# 9644  Foot Locker   2021-01-24  Northeast  New Hampshire   Manchester
# 9645  Foot Locker   2021-02-22  Northeast  New Hampshire   Manchester
# 9646  Foot Locker   2021-02-22  Northeast  New Hampshire   Manchester
# 9647  Foot Locker   2021-02-22  Northeast  New Hampshire   Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# ...

# %%
sns.boxplot(df['Operating Profit'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Operating Profit'>

# %%
sns.boxplot(df['Operating Margin'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Operating Margin'>

# %%
q1=df['Operating Margin'].quantile(0.25)

# %%
q3=df['Operating Margin'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['Operating Margin']>lower) & (df['Operating Margin']<upper) ]

# %%
df
# Out:
#          Retailer Invoice Date     Region          State         City  \
# 285   Foot Locker   2021-06-01       West     California  Los Angeles
# 286   Foot Locker   2021-06-02       West     California  Los Angeles
# 287   Foot Locker   2021-06-03       West     California  Los Angeles
# 288   Foot Locker   2021-06-04    Midwest       Illinois      Chicago
# 291   Foot Locker   2021-06-07    Midwest       Illinois      Chicago
# ...           ...          ...        ...            ...          ...
# 9643  Foot Locker   2021-01-24  Northeast  New Hampshire   Manchester
# 9644  Foot Locker   2021-01-24  Northeast  New Hampshire   Manchester
# 9645  Foot Locker   2021-02-22  Northeast  New Hampshire   Manchester
# 9646  Foot Locker   2021-02-22  Northeast  New Hampshire   Manchester
# 9647  Foot Locker   2021-02-22  Northeast  New Hampshire   Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# ...

# %%
sns.boxplot(df['Operating Margin'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Operating Margin'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7280 entries, 285 to 9647
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          7280 non-null   object
#  1   Invoice Date      7280 non-null   datetime64[ns]
#  2   Region            7280 non-null   object
#  3   State             7280 non-null   object
#  4   City              7280 non-null   object
#  5   Product           7280 non-null   object
#  6   Price per Unit    7280 non-null   float64
#  7   Units Sold        7280 non-null   int64
#  8   Total Sales       7280 non-null   float64
#  9   Operating Profit  7280 non-null   float64
#  10  Operating Margin  7280 non-null   float64
#  11  Sales Method      7280 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(6)
# memory usage: 739.4+ KB

# %%
df
# Out:
#          Retailer Invoice Date     Region          State         City  \
# 285   Foot Locker   2021-06-01       West     California  Los Angeles
# 286   Foot Locker   2021-06-02       West     California  Los Angeles
# 287   Foot Locker   2021-06-03       West     California  Los Angeles
# 288   Foot Locker   2021-06-04    Midwest       Illinois      Chicago
# 291   Foot Locker   2021-06-07    Midwest       Illinois      Chicago
# ...           ...          ...        ...            ...          ...
# 9643  Foot Locker   2021-01-24  Northeast  New Hampshire   Manchester
# 9644  Foot Locker   2021-01-24  Northeast  New Hampshire   Manchester
# 9645  Foot Locker   2021-02-22  Northeast  New Hampshire   Manchester
# 9646  Foot Locker   2021-02-22  Northeast  New Hampshire   Manchester
# 9647  Foot Locker   2021-02-22  Northeast  New Hampshire   Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# ...

# %%
sns.barplot(x=df['Region'],y=df['Units Sold'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Units Sold'>

# %%
sns.barplot(x=df['Region'],y=df['Total Sales'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Total Sales'>

# %%
sns.barplot(x=df['Region'],y=df['Operating Profit'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Operating Profit'>

# %%
sns.barplot(x=df['Product'],y=df['Total Sales'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=df['Product'],y=df['Units Sold'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=df['Product'],y=df['Operating Profit'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(df['Sales Method'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sales Method', ylabel='count'>

# %%
sns.barplot(x=df['Sales Method'],y=df['Units Sold'])
# Out:
# <AxesSubplot:xlabel='Sales Method', ylabel='Units Sold'>

# %%
sns.barplot(x=df['Sales Method'],y=df['Total Sales'])
# Out:
# <AxesSubplot:xlabel='Sales Method', ylabel='Total Sales'>

# %%
sns.barplot(x=df['Sales Method'],y=df['Operating Profit'])
# Out:
# <AxesSubplot:xlabel='Sales Method', ylabel='Operating Profit'>

# %%
df
# Out:
#          Retailer Invoice Date     Region          State         City  \
# 285   Foot Locker   2021-06-01       West     California  Los Angeles
# 286   Foot Locker   2021-06-02       West     California  Los Angeles
# 287   Foot Locker   2021-06-03       West     California  Los Angeles
# 288   Foot Locker   2021-06-04    Midwest       Illinois      Chicago
# 291   Foot Locker   2021-06-07    Midwest       Illinois      Chicago
# ...           ...          ...        ...            ...          ...
# 9643  Foot Locker   2021-01-24  Northeast  New Hampshire   Manchester
# 9644  Foot Locker   2021-01-24  Northeast  New Hampshire   Manchester
# 9645  Foot Locker   2021-02-22  Northeast  New Hampshire   Manchester
# 9646  Foot Locker   2021-02-22  Northeast  New Hampshire   Manchester
# 9647  Foot Locker   2021-02-22  Northeast  New Hampshire   Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# ...

# %% [markdown]
# # Product Wise Sales Analysis

# %%
label_df=df.groupby("Product")['Total Sales'].mean().index

# %%
value_df=df.groupby("Product")['Total Sales'].mean().values

# %%
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
label_df=df.groupby("Product")['Operating Profit'].mean().index

# %%
value_df=df.groupby("Product")['Operating Profit'].mean().values

# %%
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
label_df=df.groupby("Product")['Units Sold'].mean().index

# %%
value_df=df.groupby("Product")['Units Sold'].mean().values

# %%
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
df
# Out:
#          Retailer Invoice Date     Region          State         City  \
# 285   Foot Locker   2021-06-01       West     California  Los Angeles
# 286   Foot Locker   2021-06-02       West     California  Los Angeles
# 287   Foot Locker   2021-06-03       West     California  Los Angeles
# 288   Foot Locker   2021-06-04    Midwest       Illinois      Chicago
# 291   Foot Locker   2021-06-07    Midwest       Illinois      Chicago
# ...           ...          ...        ...            ...          ...
# 9643  Foot Locker   2021-01-24  Northeast  New Hampshire   Manchester
# 9644  Foot Locker   2021-01-24  Northeast  New Hampshire   Manchester
# 9645  Foot Locker   2021-02-22  Northeast  New Hampshire   Manchester
# 9646  Foot Locker   2021-02-22  Northeast  New Hampshire   Manchester
# 9647  Foot Locker   2021-02-22  Northeast  New Hampshire   Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# ...

# %%
label_df=df.groupby(["Product","Sales Method"]).size().sort_values(ascending=False).index

# %%
value_df=df.groupby(["Product","Sales Method"]).size().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
label_df=df.groupby(["Product","Region"]).size().sort_values(ascending=False).index

# %%
value_df=df.groupby(["Product","Region"]).size().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
df
# Out:
#          Retailer Invoice Date     Region          State         City  \
# 285   Foot Locker   2021-06-01       West     California  Los Angeles
# 286   Foot Locker   2021-06-02       West     California  Los Angeles
# 287   Foot Locker   2021-06-03       West     California  Los Angeles
# 288   Foot Locker   2021-06-04    Midwest       Illinois      Chicago
# 291   Foot Locker   2021-06-07    Midwest       Illinois      Chicago
# ...           ...          ...        ...            ...          ...
# 9643  Foot Locker   2021-01-24  Northeast  New Hampshire   Manchester
# 9644  Foot Locker   2021-01-24  Northeast  New Hampshire   Manchester
# 9645  Foot Locker   2021-02-22  Northeast  New Hampshire   Manchester
# 9646  Foot Locker   2021-02-22  Northeast  New Hampshire   Manchester
# 9647  Foot Locker   2021-02-22  Northeast  New Hampshire   Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# ...

# %%
df['Month']=pd.to_datetime(df['Invoice Date']).dt.month
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_26408\3155015547.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Month']=pd.to_datetime(df['Invoice Date']).dt.month

# %%
df['Year']=pd.to_datetime(df['Invoice Date']).dt.year
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_26408\2719338832.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year']=pd.to_datetime(df['Invoice Date']).dt.year

# %%
df['day']=pd.to_datetime(df['Invoice Date']).dt.day
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_26408\2234625797.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day']=pd.to_datetime(df['Invoice Date']).dt.day

# %%
df
# Out:
#          Retailer Invoice Date     Region          State         City  \
# 285   Foot Locker   2021-06-01       West     California  Los Angeles
# 286   Foot Locker   2021-06-02       West     California  Los Angeles
# 287   Foot Locker   2021-06-03       West     California  Los Angeles
# 288   Foot Locker   2021-06-04    Midwest       Illinois      Chicago
# 291   Foot Locker   2021-06-07    Midwest       Illinois      Chicago
# ...           ...          ...        ...            ...          ...
# 9643  Foot Locker   2021-01-24  Northeast  New Hampshire   Manchester
# 9644  Foot Locker   2021-01-24  Northeast  New Hampshire   Manchester
# 9645  Foot Locker   2021-02-22  Northeast  New Hampshire   Manchester
# 9646  Foot Locker   2021-02-22  Northeast  New Hampshire   Manchester
# 9647  Foot Locker   2021-02-22  Northeast  New Hampshire   Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# ...

# %%
df=df.drop("Invoice Date",axis=1)

# %%
df
# Out:
#          Retailer     Region          State         City  \
# 285   Foot Locker       West     California  Los Angeles
# 286   Foot Locker       West     California  Los Angeles
# 287   Foot Locker       West     California  Los Angeles
# 288   Foot Locker    Midwest       Illinois      Chicago
# 291   Foot Locker    Midwest       Illinois      Chicago
# ...           ...        ...            ...          ...
# 9643  Foot Locker  Northeast  New Hampshire   Manchester
# 9644  Foot Locker  Northeast  New Hampshire   Manchester
# 9645  Foot Locker  Northeast  New Hampshire   Manchester
# 9646  Foot Locker  Northeast  New Hampshire   Manchester
# 9647  Foot Locker  Northeast  New Hampshire   Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# 285     Men's Athletic Footwear            45.0         275     123750.0
# 286     Women's Street Footwear            35.0         275      96250.0
# ...

# %% [markdown]
# # Year Wise Sales Analysis

# %%
sns.barplot(x=df['Year'],y=df['Total Sales'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total Sales'>

# %%
sns.barplot(x=df['Year'],y=df['Operating Profit'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Operating Profit'>

# %%
sns.barplot(x=df['Year'],y=df['Units Sold'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Units Sold'>

# %%
sns.boxplot(x=df['Year'],y=df['Total Sales'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total Sales'>

# %%
sns.boxplot(x=df['Year'],y=df['Units Sold'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Units Sold'>

# %%
sns.boxplot(x=df['Year'],y=df['Operating Profit'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Operating Profit'>

# %%
df
# Out:
#          Retailer     Region          State         City  \
# 285   Foot Locker       West     California  Los Angeles
# 286   Foot Locker       West     California  Los Angeles
# 287   Foot Locker       West     California  Los Angeles
# 288   Foot Locker    Midwest       Illinois      Chicago
# 291   Foot Locker    Midwest       Illinois      Chicago
# ...           ...        ...            ...          ...
# 9643  Foot Locker  Northeast  New Hampshire   Manchester
# 9644  Foot Locker  Northeast  New Hampshire   Manchester
# 9645  Foot Locker  Northeast  New Hampshire   Manchester
# 9646  Foot Locker  Northeast  New Hampshire   Manchester
# 9647  Foot Locker  Northeast  New Hampshire   Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# 285     Men's Athletic Footwear            45.0         275     123750.0
# 286     Women's Street Footwear            35.0         275      96250.0
# ...

# %% [markdown]
# # Sales based on Retailer

# %%
sns.barplot(x=df['Retailer'],y=df['Total Sales'])
# Out:
# <AxesSubplot:xlabel='Retailer', ylabel='Total Sales'>

# %%
sns.barplot(x=df['Retailer'],y=df['Operating Profit'])
# Out:
# <AxesSubplot:xlabel='Retailer', ylabel='Operating Profit'>

# %%
label_df=df.groupby(['Retailer','Year'])['Total Sales'].mean().sort_values(ascending=False).index

# %%
value_df=df.groupby(['Retailer','Year'])['Total Sales'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Sales based on Region

# %%
df
# Out:
#          Retailer     Region          State         City  \
# 285   Foot Locker       West     California  Los Angeles
# 286   Foot Locker       West     California  Los Angeles
# 287   Foot Locker       West     California  Los Angeles
# 288   Foot Locker    Midwest       Illinois      Chicago
# 291   Foot Locker    Midwest       Illinois      Chicago
# ...           ...        ...            ...          ...
# 9643  Foot Locker  Northeast  New Hampshire   Manchester
# 9644  Foot Locker  Northeast  New Hampshire   Manchester
# 9645  Foot Locker  Northeast  New Hampshire   Manchester
# 9646  Foot Locker  Northeast  New Hampshire   Manchester
# 9647  Foot Locker  Northeast  New Hampshire   Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# 285     Men's Athletic Footwear            45.0         275     123750.0
# 286     Women's Street Footwear            35.0         275      96250.0
# ...

# %%
label_df=df.groupby(['Region','Year'])['Total Sales'].mean().sort_values(ascending=False).index

# %%
value_df=df.groupby(['Region','Year'])['Total Sales'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Sales based on State

# %%
label_df=df.groupby(['State','Year'])['Total Sales'].mean().sort_values(ascending=False).index

# %%
value_df=df.groupby(['State','Year'])['Total Sales'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df[:15],labels=label_df[:15],autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Sales based on City

# %%
label_df=df.groupby(['City','Year'])['Total Sales'].mean().sort_values(ascending=False).index

# %%
value_df=df.groupby(['City','Year'])['Total Sales'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df[:15],labels=label_df[:15],autopct="%1.2f%%")
plt.show()

# %%
df
# Out:
#          Retailer     Region          State         City  \
# 285   Foot Locker       West     California  Los Angeles
# 286   Foot Locker       West     California  Los Angeles
# 287   Foot Locker       West     California  Los Angeles
# 288   Foot Locker    Midwest       Illinois      Chicago
# 291   Foot Locker    Midwest       Illinois      Chicago
# ...           ...        ...            ...          ...
# 9643  Foot Locker  Northeast  New Hampshire   Manchester
# 9644  Foot Locker  Northeast  New Hampshire   Manchester
# 9645  Foot Locker  Northeast  New Hampshire   Manchester
# 9646  Foot Locker  Northeast  New Hampshire   Manchester
# 9647  Foot Locker  Northeast  New Hampshire   Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# 285     Men's Athletic Footwear            45.0         275     123750.0
# 286     Women's Street Footwear            35.0         275      96250.0
# ...

# %% [markdown]
# # Sales based on Year

# %%
label_df=df.groupby('Year')['Total Sales'].mean().sort_values(ascending=False).index

# %%
value_df=df.groupby('Year')['Total Sales'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df[:15],labels=label_df[:15],autopct="%1.2f%%")
plt.show()

# %%
df
# Out:
#          Retailer     Region          State         City  \
# 285   Foot Locker       West     California  Los Angeles
# 286   Foot Locker       West     California  Los Angeles
# 287   Foot Locker       West     California  Los Angeles
# 288   Foot Locker    Midwest       Illinois      Chicago
# 291   Foot Locker    Midwest       Illinois      Chicago
# ...           ...        ...            ...          ...
# 9643  Foot Locker  Northeast  New Hampshire   Manchester
# 9644  Foot Locker  Northeast  New Hampshire   Manchester
# 9645  Foot Locker  Northeast  New Hampshire   Manchester
# 9646  Foot Locker  Northeast  New Hampshire   Manchester
# 9647  Foot Locker  Northeast  New Hampshire   Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# 285     Men's Athletic Footwear            45.0         275     123750.0
# 286     Women's Street Footwear            35.0         275      96250.0
# ...

# %% [markdown]
# # Sales for New York State

# %%
df
# Out:
#          Retailer     Region          State         City  \
# 285   Foot Locker       West     California  Los Angeles
# 286   Foot Locker       West     California  Los Angeles
# 287   Foot Locker       West     California  Los Angeles
# 288   Foot Locker    Midwest       Illinois      Chicago
# 291   Foot Locker    Midwest       Illinois      Chicago
# ...           ...        ...            ...          ...
# 9643  Foot Locker  Northeast  New Hampshire   Manchester
# 9644  Foot Locker  Northeast  New Hampshire   Manchester
# 9645  Foot Locker  Northeast  New Hampshire   Manchester
# 9646  Foot Locker  Northeast  New Hampshire   Manchester
# 9647  Foot Locker  Northeast  New Hampshire   Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# 285     Men's Athletic Footwear            45.0         275     123750.0
# 286     Women's Street Footwear            35.0         275      96250.0
# ...

# %%
New_York_df=df.groupby("State").get_group("New York")

# %%
New_York_df
# Out:
#            Retailer     Region     State      City                    Product  \
# 1440      West Gear  Northeast  New York    Albany  Women's Athletic Footwear
# 1445      West Gear  Northeast  New York    Albany    Women's Street Footwear
# 1446      West Gear  Northeast  New York    Albany  Women's Athletic Footwear
# 1451      West Gear  Northeast  New York    Albany    Women's Street Footwear
# 1452      West Gear  Northeast  New York    Albany  Women's Athletic Footwear
# ...             ...        ...       ...       ...                        ...
# 7843        Walmart  Northeast  New York  New York            Women's Apparel
# 7844  Sports Direct  Northeast  New York  New York      Men's Street Footwear
# 7845  Sports Direct  Northeast  New York  New York    Men's Athletic Footwear
# 7846  Sports Direct  Northeast  New York  New York    Women's Street Footwear
# 7847  Sports Direct  Northeast  New York  New York  Women's Athletic Footwear
#
# ...

# %%
sns.countplot(New_York_df['Sales Method'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sales Method', ylabel='count'>

# %%
sns.countplot(New_York_df['Retailer'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Retailer', ylabel='count'>

# %%
sns.barplot(x=New_York_df['Product'],y=New_York_df['Total Sales'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=New_York_df['Product'],y=New_York_df['Operating Profit'])
plt.xticks(rotation=90)
plt.show()

# %%
New_York_df
# Out:
#            Retailer     Region     State      City                    Product  \
# 1440      West Gear  Northeast  New York    Albany  Women's Athletic Footwear
# 1445      West Gear  Northeast  New York    Albany    Women's Street Footwear
# 1446      West Gear  Northeast  New York    Albany  Women's Athletic Footwear
# 1451      West Gear  Northeast  New York    Albany    Women's Street Footwear
# 1452      West Gear  Northeast  New York    Albany  Women's Athletic Footwear
# ...             ...        ...       ...       ...                        ...
# 7843        Walmart  Northeast  New York  New York            Women's Apparel
# 7844  Sports Direct  Northeast  New York  New York      Men's Street Footwear
# 7845  Sports Direct  Northeast  New York  New York    Men's Athletic Footwear
# 7846  Sports Direct  Northeast  New York  New York    Women's Street Footwear
# 7847  Sports Direct  Northeast  New York  New York  Women's Athletic Footwear
#
# ...

# %%
sns.barplot(x=New_York_df['Year'],y=New_York_df['Total Sales'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total Sales'>

# %%
label_df=New_York_df.groupby("Product")['Total Sales'].mean().sort_values(ascending=False).index

# %%
value_df=New_York_df.groupby("Product")['Total Sales'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
label_df=New_York_df.groupby("Product")['Operating Profit'].mean().sort_values(ascending=False).index

# %%
value_df=New_York_df.groupby("Product")['Operating Profit'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
New_York_df
# Out:
#            Retailer     Region     State      City                    Product  \
# 1440      West Gear  Northeast  New York    Albany  Women's Athletic Footwear
# 1445      West Gear  Northeast  New York    Albany    Women's Street Footwear
# 1446      West Gear  Northeast  New York    Albany  Women's Athletic Footwear
# 1451      West Gear  Northeast  New York    Albany    Women's Street Footwear
# 1452      West Gear  Northeast  New York    Albany  Women's Athletic Footwear
# ...             ...        ...       ...       ...                        ...
# 7843        Walmart  Northeast  New York  New York            Women's Apparel
# 7844  Sports Direct  Northeast  New York  New York      Men's Street Footwear
# 7845  Sports Direct  Northeast  New York  New York    Men's Athletic Footwear
# 7846  Sports Direct  Northeast  New York  New York    Women's Street Footwear
# 7847  Sports Direct  Northeast  New York  New York  Women's Athletic Footwear
#
# ...

# %%
label_df=New_York_df.groupby("Product")['Units Sold'].mean().sort_values(ascending=False).index

# %%
value_df=New_York_df.groupby("Product")['Units Sold'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
label_df=New_York_df.groupby("Retailer")['Units Sold'].mean().sort_values(ascending=False).index

# %%
value_df=New_York_df.groupby("Retailer")['Units Sold'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
New_York_df
# Out:
#            Retailer     Region     State      City                    Product  \
# 1440      West Gear  Northeast  New York    Albany  Women's Athletic Footwear
# 1445      West Gear  Northeast  New York    Albany    Women's Street Footwear
# 1446      West Gear  Northeast  New York    Albany  Women's Athletic Footwear
# 1451      West Gear  Northeast  New York    Albany    Women's Street Footwear
# 1452      West Gear  Northeast  New York    Albany  Women's Athletic Footwear
# ...             ...        ...       ...       ...                        ...
# 7843        Walmart  Northeast  New York  New York            Women's Apparel
# 7844  Sports Direct  Northeast  New York  New York      Men's Street Footwear
# 7845  Sports Direct  Northeast  New York  New York    Men's Athletic Footwear
# 7846  Sports Direct  Northeast  New York  New York    Women's Street Footwear
# 7847  Sports Direct  Northeast  New York  New York  Women's Athletic Footwear
#
# ...

# %%
df
# Out:
#          Retailer     Region          State         City  \
# 285   Foot Locker       West     California  Los Angeles
# 286   Foot Locker       West     California  Los Angeles
# 287   Foot Locker       West     California  Los Angeles
# 288   Foot Locker    Midwest       Illinois      Chicago
# 291   Foot Locker    Midwest       Illinois      Chicago
# ...           ...        ...            ...          ...
# 9643  Foot Locker  Northeast  New Hampshire   Manchester
# 9644  Foot Locker  Northeast  New Hampshire   Manchester
# 9645  Foot Locker  Northeast  New Hampshire   Manchester
# 9646  Foot Locker  Northeast  New Hampshire   Manchester
# 9647  Foot Locker  Northeast  New Hampshire   Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# 285     Men's Athletic Footwear            45.0         275     123750.0
# 286     Women's Street Footwear            35.0         275      96250.0
# ...

# %% [markdown]
# # Sales for Northeast Region

# %%
Northeast_df=df.groupby("Region").get_group("Northeast")

# %%
Northeast_df
# Out:
#          Retailer     Region          State          City  \
# 432   Foot Locker  Northeast   Pennsylvania  Philadelphia
# 433   Foot Locker  Northeast   Pennsylvania  Philadelphia
# 435   Foot Locker  Northeast   Pennsylvania  Philadelphia
# 436   Foot Locker  Northeast   Pennsylvania  Philadelphia
# 437   Foot Locker  Northeast   Pennsylvania  Philadelphia
# ...           ...        ...            ...           ...
# 9643  Foot Locker  Northeast  New Hampshire    Manchester
# 9644  Foot Locker  Northeast  New Hampshire    Manchester
# 9645  Foot Locker  Northeast  New Hampshire    Manchester
# 9646  Foot Locker  Northeast  New Hampshire    Manchester
# 9647  Foot Locker  Northeast  New Hampshire    Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# 432               Men's Apparel            55.0         125      68750.0
# 433             Women's Apparel            45.0         225     101250.0
# ...

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Northeast_df['Product'])
plt.show()

# %%
Northeast_df
# Out:
#          Retailer     Region          State          City  \
# 432   Foot Locker  Northeast   Pennsylvania  Philadelphia
# 433   Foot Locker  Northeast   Pennsylvania  Philadelphia
# 435   Foot Locker  Northeast   Pennsylvania  Philadelphia
# 436   Foot Locker  Northeast   Pennsylvania  Philadelphia
# 437   Foot Locker  Northeast   Pennsylvania  Philadelphia
# ...           ...        ...            ...           ...
# 9643  Foot Locker  Northeast  New Hampshire    Manchester
# 9644  Foot Locker  Northeast  New Hampshire    Manchester
# 9645  Foot Locker  Northeast  New Hampshire    Manchester
# 9646  Foot Locker  Northeast  New Hampshire    Manchester
# 9647  Foot Locker  Northeast  New Hampshire    Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# 432               Men's Apparel            55.0         125      68750.0
# 433             Women's Apparel            45.0         225     101250.0
# ...

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Northeast_df['City'])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Northeast_df['State'])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Northeast_df['Retailer'])
plt.show()

# %%
Northeast_df
# Out:
#          Retailer     Region          State          City  \
# 432   Foot Locker  Northeast   Pennsylvania  Philadelphia
# 433   Foot Locker  Northeast   Pennsylvania  Philadelphia
# 435   Foot Locker  Northeast   Pennsylvania  Philadelphia
# 436   Foot Locker  Northeast   Pennsylvania  Philadelphia
# 437   Foot Locker  Northeast   Pennsylvania  Philadelphia
# ...           ...        ...            ...           ...
# 9643  Foot Locker  Northeast  New Hampshire    Manchester
# 9644  Foot Locker  Northeast  New Hampshire    Manchester
# 9645  Foot Locker  Northeast  New Hampshire    Manchester
# 9646  Foot Locker  Northeast  New Hampshire    Manchester
# 9647  Foot Locker  Northeast  New Hampshire    Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# 432               Men's Apparel            55.0         125      68750.0
# 433             Women's Apparel            45.0         225     101250.0
# ...

# %%
sns.barplot(x=Northeast_df['Year'],y=Northeast_df['Total Sales'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total Sales'>

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=Northeast_df['City'],y=Northeast_df['Total Sales'])
plt.xticks(rotation=90)
plt.show()

# %%
Northeast_df
# Out:
#          Retailer     Region          State          City  \
# 432   Foot Locker  Northeast   Pennsylvania  Philadelphia
# 433   Foot Locker  Northeast   Pennsylvania  Philadelphia
# 435   Foot Locker  Northeast   Pennsylvania  Philadelphia
# 436   Foot Locker  Northeast   Pennsylvania  Philadelphia
# 437   Foot Locker  Northeast   Pennsylvania  Philadelphia
# ...           ...        ...            ...           ...
# 9643  Foot Locker  Northeast  New Hampshire    Manchester
# 9644  Foot Locker  Northeast  New Hampshire    Manchester
# 9645  Foot Locker  Northeast  New Hampshire    Manchester
# 9646  Foot Locker  Northeast  New Hampshire    Manchester
# 9647  Foot Locker  Northeast  New Hampshire    Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# 432               Men's Apparel            55.0         125      68750.0
# 433             Women's Apparel            45.0         225     101250.0
# ...

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=Northeast_df['City'],y=Northeast_df['Operating Profit'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=Northeast_df['Product'],y=Northeast_df['Total Sales'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=Northeast_df['Product'],y=Northeast_df['Operating Profit'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=Northeast_df['Product'],y=Northeast_df['Units Sold'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=Northeast_df['State'],y=Northeast_df['Units Sold'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=Northeast_df['State'],y=Northeast_df['Operating Profit'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=Northeast_df['Retailer'],y=Northeast_df['Operating Profit'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=Northeast_df['Retailer'],y=Northeast_df['Units Sold'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=Northeast_df['Product'],y=Northeast_df['Price per Unit'])
plt.xticks(rotation=90)
plt.show()

# %%
df
# Out:
#          Retailer     Region          State         City  \
# 285   Foot Locker       West     California  Los Angeles
# 286   Foot Locker       West     California  Los Angeles
# 287   Foot Locker       West     California  Los Angeles
# 288   Foot Locker    Midwest       Illinois      Chicago
# 291   Foot Locker    Midwest       Illinois      Chicago
# ...           ...        ...            ...          ...
# 9643  Foot Locker  Northeast  New Hampshire   Manchester
# 9644  Foot Locker  Northeast  New Hampshire   Manchester
# 9645  Foot Locker  Northeast  New Hampshire   Manchester
# 9646  Foot Locker  Northeast  New Hampshire   Manchester
# 9647  Foot Locker  Northeast  New Hampshire   Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# 285     Men's Athletic Footwear            45.0         275     123750.0
# 286     Women's Street Footwear            35.0         275      96250.0
# ...

# %% [markdown]
# # Sales,Unit Sold and Operating Profile According To Day,Month and Year

# %%
sns.barplot(x=df['Month'],y=df['Total Sales'])
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Total Sales'>

# %%
sns.barplot(x=df['Month'],y=df['Operating Profit'])
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Operating Profit'>

# %%
sns.barplot(x=df['Month'],y=df['Units Sold'])
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Units Sold'>

# %%
sns.countplot(x=df['Month'])
# Out:
# <AxesSubplot:xlabel='Month', ylabel='count'>

# %%
sns.lineplot(x=df['Month'],y=df['Total Sales'])
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Total Sales'>

# %%
sns.lineplot(x=df['Year'],y=df['Total Sales'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total Sales'>

# %%
sns.lineplot(x=df['day'],y=df['Total Sales'])
# Out:
# <AxesSubplot:xlabel='day', ylabel='Total Sales'>

# %%
sns.lineplot(x=df['day'],y=df['Total Sales'],hue=df['Year'])
# Out:
# <AxesSubplot:xlabel='day', ylabel='Total Sales'>

# %%
sns.lineplot(x=df['Month'],y=df['Operating Profit'])
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Operating Profit'>

# %%
sns.lineplot(x=df['Year'],y=df['Operating Profit'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Operating Profit'>

# %%
sns.lineplot(x=df['day'],y=df['Operating Profit'])
# Out:
# <AxesSubplot:xlabel='day', ylabel='Operating Profit'>

# %%
sns.lineplot(x=df['day'],y=df['Operating Profit'],hue=df['Year'])
# Out:
# <AxesSubplot:xlabel='day', ylabel='Operating Profit'>

# %%
sns.lineplot(x=df['day'],y=df['Total Sales'],hue=df['Year'])
# Out:
# <AxesSubplot:xlabel='day', ylabel='Total Sales'>

# %% [markdown]
# # Sales based on Sales Method

# %%
df
# Out:
#          Retailer     Region          State         City  \
# 285   Foot Locker       West     California  Los Angeles
# 286   Foot Locker       West     California  Los Angeles
# 287   Foot Locker       West     California  Los Angeles
# 288   Foot Locker    Midwest       Illinois      Chicago
# 291   Foot Locker    Midwest       Illinois      Chicago
# ...           ...        ...            ...          ...
# 9643  Foot Locker  Northeast  New Hampshire   Manchester
# 9644  Foot Locker  Northeast  New Hampshire   Manchester
# 9645  Foot Locker  Northeast  New Hampshire   Manchester
# 9646  Foot Locker  Northeast  New Hampshire   Manchester
# 9647  Foot Locker  Northeast  New Hampshire   Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# 285     Men's Athletic Footwear            45.0         275     123750.0
# 286     Women's Street Footwear            35.0         275      96250.0
# ...

# %%
sales_method_df=df.groupby("Sales Method").get_group("Outlet")

# %%
sales_method_df
# Out:
#          Retailer     Region          State         City  \
# 285   Foot Locker       West     California  Los Angeles
# 286   Foot Locker       West     California  Los Angeles
# 287   Foot Locker       West     California  Los Angeles
# 288   Foot Locker    Midwest       Illinois      Chicago
# 291   Foot Locker    Midwest       Illinois      Chicago
# ...           ...        ...            ...          ...
# 9643  Foot Locker  Northeast  New Hampshire   Manchester
# 9644  Foot Locker  Northeast  New Hampshire   Manchester
# 9645  Foot Locker  Northeast  New Hampshire   Manchester
# 9646  Foot Locker  Northeast  New Hampshire   Manchester
# 9647  Foot Locker  Northeast  New Hampshire   Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# 285     Men's Athletic Footwear            45.0         275     123750.0
# 286     Women's Street Footwear            35.0         275      96250.0
# ...

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=sales_method_df['Product'])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=sales_method_df['City'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=sales_method_df['State'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=sales_method_df['Region'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=sales_method_df['Retailer'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x=sales_method_df['Year'])
plt.xticks(rotation=90)
plt.show()

# %%
sales_method_df
# Out:
#          Retailer     Region          State         City  \
# 285   Foot Locker       West     California  Los Angeles
# 286   Foot Locker       West     California  Los Angeles
# 287   Foot Locker       West     California  Los Angeles
# 288   Foot Locker    Midwest       Illinois      Chicago
# 291   Foot Locker    Midwest       Illinois      Chicago
# ...           ...        ...            ...          ...
# 9643  Foot Locker  Northeast  New Hampshire   Manchester
# 9644  Foot Locker  Northeast  New Hampshire   Manchester
# 9645  Foot Locker  Northeast  New Hampshire   Manchester
# 9646  Foot Locker  Northeast  New Hampshire   Manchester
# 9647  Foot Locker  Northeast  New Hampshire   Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# 285     Men's Athletic Footwear            45.0         275     123750.0
# 286     Women's Street Footwear            35.0         275      96250.0
# ...

# %%
sns.barplot(x=sales_method_df['Product'],y=sales_method_df['Total Sales'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=sales_method_df['Product'],y=sales_method_df['Units Sold'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=sales_method_df['Product'],y=sales_method_df['Operating Profit'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=sales_method_df['Product'],y=sales_method_df['Price per Unit'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=sales_method_df['Product'],y=sales_method_df['Operating Margin'])
plt.xticks(rotation=90)
plt.show()

# %%
sales_method_df
# Out:
#          Retailer     Region          State         City  \
# 285   Foot Locker       West     California  Los Angeles
# 286   Foot Locker       West     California  Los Angeles
# 287   Foot Locker       West     California  Los Angeles
# 288   Foot Locker    Midwest       Illinois      Chicago
# 291   Foot Locker    Midwest       Illinois      Chicago
# ...           ...        ...            ...          ...
# 9643  Foot Locker  Northeast  New Hampshire   Manchester
# 9644  Foot Locker  Northeast  New Hampshire   Manchester
# 9645  Foot Locker  Northeast  New Hampshire   Manchester
# 9646  Foot Locker  Northeast  New Hampshire   Manchester
# 9647  Foot Locker  Northeast  New Hampshire   Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# 285     Men's Athletic Footwear            45.0         275     123750.0
# 286     Women's Street Footwear            35.0         275      96250.0
# ...

# %%
sns.countplot(sales_method_df['Month'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Month', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
sns.countplot(sales_method_df['day'])
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sales_method_df
# Out:
#          Retailer     Region          State         City  \
# 285   Foot Locker       West     California  Los Angeles
# 286   Foot Locker       West     California  Los Angeles
# 287   Foot Locker       West     California  Los Angeles
# 288   Foot Locker    Midwest       Illinois      Chicago
# 291   Foot Locker    Midwest       Illinois      Chicago
# ...           ...        ...            ...          ...
# 9643  Foot Locker  Northeast  New Hampshire   Manchester
# 9644  Foot Locker  Northeast  New Hampshire   Manchester
# 9645  Foot Locker  Northeast  New Hampshire   Manchester
# 9646  Foot Locker  Northeast  New Hampshire   Manchester
# 9647  Foot Locker  Northeast  New Hampshire   Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# 285     Men's Athletic Footwear            45.0         275     123750.0
# 286     Women's Street Footwear            35.0         275      96250.0
# ...

# %%
label_df=sales_method_df.groupby(["Region","State"])['Total Sales'].mean().sort_values(ascending=False).index

# %%
value_df=sales_method_df.groupby(["Region","State"])['Total Sales'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df[:15],labels=label_df[:15],autopct="%1.2f%%")
plt.show()

# %%
label_df=sales_method_df.groupby(["Region","Retailer"])['Total Sales'].mean().sort_values(ascending=False).index

# %%
value_df=sales_method_df.groupby(["Region","Retailer"])['Total Sales'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df[:15],labels=label_df[:15],autopct="%1.2f%%")
plt.show()

# %%
label_df=sales_method_df.groupby(["Region","Product"])['Total Sales'].mean().sort_values(ascending=False).index

# %%
value_df=sales_method_df.groupby(["Region","Product"])['Total Sales'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df[:15],labels=label_df[:15],autopct="%1.2f%%")
plt.show()

# %%
label_df=sales_method_df.groupby(["State","Product"])['Total Sales'].mean().sort_values(ascending=False).index

# %%
value_df=sales_method_df.groupby(["State","Product"])['Total Sales'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df[:15],labels=label_df[:15],autopct="%1.2f%%")
plt.show()

# %%
sales_method_df
# Out:
#          Retailer     Region          State         City  \
# 285   Foot Locker       West     California  Los Angeles
# 286   Foot Locker       West     California  Los Angeles
# 287   Foot Locker       West     California  Los Angeles
# 288   Foot Locker    Midwest       Illinois      Chicago
# 291   Foot Locker    Midwest       Illinois      Chicago
# ...           ...        ...            ...          ...
# 9643  Foot Locker  Northeast  New Hampshire   Manchester
# 9644  Foot Locker  Northeast  New Hampshire   Manchester
# 9645  Foot Locker  Northeast  New Hampshire   Manchester
# 9646  Foot Locker  Northeast  New Hampshire   Manchester
# 9647  Foot Locker  Northeast  New Hampshire   Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# 285     Men's Athletic Footwear            45.0         275     123750.0
# 286     Women's Street Footwear            35.0         275      96250.0
# ...

# %%
label_df=sales_method_df.groupby("Month")['Total Sales'].mean().sort_values(ascending=False).index

# %%
value_df=sales_method_df.groupby("Month")['Total Sales'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
label_df=sales_method_df.groupby("Year")['Total Sales'].mean().sort_values(ascending=False).index

# %%
value_df=sales_method_df.groupby("Year")['Total Sales'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
sales_method_df
# Out:
#          Retailer     Region          State         City  \
# 285   Foot Locker       West     California  Los Angeles
# 286   Foot Locker       West     California  Los Angeles
# 287   Foot Locker       West     California  Los Angeles
# 288   Foot Locker    Midwest       Illinois      Chicago
# 291   Foot Locker    Midwest       Illinois      Chicago
# ...           ...        ...            ...          ...
# 9643  Foot Locker  Northeast  New Hampshire   Manchester
# 9644  Foot Locker  Northeast  New Hampshire   Manchester
# 9645  Foot Locker  Northeast  New Hampshire   Manchester
# 9646  Foot Locker  Northeast  New Hampshire   Manchester
# 9647  Foot Locker  Northeast  New Hampshire   Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# 285     Men's Athletic Footwear            45.0         275     123750.0
# 286     Women's Street Footwear            35.0         275      96250.0
# ...

# %%
label_df=sales_method_df.groupby("Region")['Operating Profit'].mean().sort_values(ascending=False).index

# %%
value_df=sales_method_df.groupby("Region")['Operating Profit'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
label_df=sales_method_df.groupby("Region")['Total Sales'].mean().sort_values(ascending=False).index

# %%
value_df=sales_method_df.groupby("Region")['Total Sales'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
label_df=sales_method_df.groupby(["Region","Product"])['Units Sold'].mean().sort_values(ascending=False).index

# %%
value_df=sales_method_df.groupby(["Region","Product"])['Units Sold'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df[:15],labels=label_df[:15],autopct="%1.2f%%")
plt.show()

# %%
label_df=sales_method_df.groupby("Product")['Units Sold'].mean().sort_values(ascending=False).index

# %%
value_df=sales_method_df.groupby("Product")['Units Sold'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
label_df=sales_method_df.groupby("Region")['Units Sold'].mean().sort_values(ascending=False).index

# %%
value_df=sales_method_df.groupby("Region")['Units Sold'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
label_df=sales_method_df.groupby(["City","Product"])['Total Sales'].mean().sort_values(ascending=False).index

# %%
value_df=sales_method_df.groupby(["City","Product"])['Total Sales'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df[:15],labels=label_df[:15],autopct="%1.2f%%")
plt.show()

# %%
label_df=sales_method_df.groupby("City")['Units Sold'].mean().sort_values(ascending=False).index

# %%
value_df=sales_method_df.groupby("City")['Units Sold'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df[:15],labels=label_df[:15],autopct="%1.2f%%")
plt.show()

# %%
label_df=sales_method_df.groupby("City")['Operating Profit'].mean().sort_values(ascending=False).index

# %%
value_df=sales_method_df.groupby("City")['Operating Profit'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df[:15],labels=label_df[:15],autopct="%1.2f%%")
plt.show()

# %%
label_df=sales_method_df.groupby("Product")['Operating Profit'].mean().sort_values(ascending=False).index

# %%
value_df=sales_method_df.groupby("Product")['Operating Profit'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
label_df=sales_method_df.groupby("Month")['Operating Profit'].mean().sort_values(ascending=False).index

# %%
value_df=sales_method_df.groupby("Month")['Operating Profit'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
label_df=sales_method_df.groupby("Year")['Operating Profit'].mean().sort_values(ascending=False).index

# %%
value_df=sales_method_df.groupby("Year")['Operating Profit'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
label_df=sales_method_df.groupby("Retailer")['Operating Profit'].mean().sort_values(ascending=False).index

# %%
value_df=sales_method_df.groupby("Retailer")['Operating Profit'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
sales_method_df
# Out:
#          Retailer     Region          State         City  \
# 285   Foot Locker       West     California  Los Angeles
# 286   Foot Locker       West     California  Los Angeles
# 287   Foot Locker       West     California  Los Angeles
# 288   Foot Locker    Midwest       Illinois      Chicago
# 291   Foot Locker    Midwest       Illinois      Chicago
# ...           ...        ...            ...          ...
# 9643  Foot Locker  Northeast  New Hampshire   Manchester
# 9644  Foot Locker  Northeast  New Hampshire   Manchester
# 9645  Foot Locker  Northeast  New Hampshire   Manchester
# 9646  Foot Locker  Northeast  New Hampshire   Manchester
# 9647  Foot Locker  Northeast  New Hampshire   Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# 285     Men's Athletic Footwear            45.0         275     123750.0
# 286     Women's Street Footwear            35.0         275      96250.0
# ...

# %%
sns.lineplot(x=sales_method_df['Year'],y=sales_method_df['Operating Profit'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Operating Profit'>

# %%
sns.lineplot(x=sales_method_df['Month'],y=sales_method_df['Operating Profit'])
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Operating Profit'>

# %%
sns.lineplot(x=sales_method_df['day'],y=sales_method_df['Operating Profit'])
# Out:
# <AxesSubplot:xlabel='day', ylabel='Operating Profit'>

# %%
sns.lineplot(x=sales_method_df['Year'],y=sales_method_df['Total Sales'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total Sales'>

# %%
sns.lineplot(x=sales_method_df['Month'],y=sales_method_df['Total Sales'])
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Total Sales'>

# %%
sns.lineplot(x=sales_method_df['day'],y=sales_method_df['Total Sales'])
# Out:
# <AxesSubplot:xlabel='day', ylabel='Total Sales'>

# %% [markdown]
# ## Find Units Sold for each product

# %%
sales_method_df
# Out:
#          Retailer     Region          State         City  \
# 285   Foot Locker       West     California  Los Angeles
# 286   Foot Locker       West     California  Los Angeles
# 287   Foot Locker       West     California  Los Angeles
# 288   Foot Locker    Midwest       Illinois      Chicago
# 291   Foot Locker    Midwest       Illinois      Chicago
# ...           ...        ...            ...          ...
# 9643  Foot Locker  Northeast  New Hampshire   Manchester
# 9644  Foot Locker  Northeast  New Hampshire   Manchester
# 9645  Foot Locker  Northeast  New Hampshire   Manchester
# 9646  Foot Locker  Northeast  New Hampshire   Manchester
# 9647  Foot Locker  Northeast  New Hampshire   Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# 285     Men's Athletic Footwear            45.0         275     123750.0
# 286     Women's Street Footwear            35.0         275      96250.0
# ...

# %%
label_df=sales_method_df.groupby("Product")['Units Sold'].sum().sort_values(ascending=False).index

# %%
value_df=sales_method_df.groupby("Product")['Units Sold'].sum().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,10))
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()
